# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
my_img = cv2.imread("./goruntu.jpg")

# %%
type(my_img)
# Out:
# numpy.ndarray

# %%
my_img.shape
# Out:
# (683, 1024, 3)

# %%
my_gray_img = cv2.cvtColor(my_img, cv2.COLOR_BGR2GRAY)

# %%
my_gray_img.shape
# Out:
# (683, 1024)

# %%
plt.imshow(my_gray_img, cmap="gray")
plt.axis("off")
# Out:
# (-0.5, 1023.5, 682.5, -0.5)

# %%
#Binary Thresh: İkili eşikleme, verilen thresh (eşik) değeri baz alınarak bu eşik değerinin altında kalan piksel değerleri 
#yani örneğin 125'ten küçük piksel değerleri siyah rengini alacak (0), büyük veya eşit olanlar ise beyaz rengini (255) alacak.

# %%
_, my_binary_thresh_img = cv2.threshold(my_gray_img, thresh=125, maxval=255, type=cv2.THRESH_BINARY)
